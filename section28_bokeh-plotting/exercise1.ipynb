# %%
from bokeh.plotting import figure
from bokeh.io import output_file, show

# %%
f1, f2 = figure(), figure()

x = [3,7.5,10]
y = [3,6,9]

f1.triangle(x,y)
f2.circle(x,y)

show(f1)
show(f2)

# %%
help(f.triangle)
# Out:
# Help on method triangle in module bokeh.plotting.figure:
#
# triangle(x={'field': 'x'}, y={'field': 'y'}, size=4, angle=0.0, *, angle_units='rad', fill_alpha=1.0, fill_color='gray', hatch_alpha=1.0, hatch_color='black', hatch_extra={}, hatch_pattern=None, hatch_scale=12.0, hatch_weight=1.0, hit_dilation=1.0, line_alpha=1.0, line_cap='butt', line_color='black', line_dash=[], line_dash_offset=0, line_join='bevel', line_width=1, name=None, syncable=True, tags=[], **kwargs) method of bokeh.plotting.figure.Figure instance
#     Configure and add :class:`~bokeh.models.glyphs.Scatter` glyphs to this Figure.
#
#     Args:
#         x (:class:`~bokeh.core.properties.NumberSpec`\ , optional):
#             The x-axis coordinates for the center of the markers.
#
#             (default: {'field': 'x'})
#
#         y (:class:`~bokeh.core.properties.NumberSpec`\ , optional):
#             The y-axis coordinates for the center of the markers.
#
#             (default: {'field': 'y'})
#
# ...
